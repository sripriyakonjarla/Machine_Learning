# %% [markdown]
# <a href="https://colab.research.google.com/github/sripriyakonjarla/Machine_Learning/blob/main/testing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.model_selection import RandomizedSearchCV, StratifiedKFold, cross_val_score
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier  # Example classifier
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
from sklearn.model_selection import GridSearchCV, StratifiedKFold
from sklearn.metrics import make_scorer, accuracy_score, precision_score, recall_score, f1_score
import pandas as pd
from sklearn.model_selection import train_test_split, RandomizedSearchCV, cross_validate
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score
import warnings
warnings.filterwarnings("ignore")
data = pd.read_excel('testing_embeddings.xlsx')

# Assume the last column is the target variable
X = data.iloc[:, :-1]  # Features
y = data.iloc[:, -1]    # Target variable

# %%
# !pip install catboost
# Out:
# Collecting catboost
#   Downloading catboost-1.2.7-cp310-cp310-manylinux2014_x86_64.whl.metadata (1.2 kB)
# Requirement already satisfied: graphviz in /usr/local/lib/python3.10/dist-packages (from catboost) (0.20.3)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.10/dist-packages (from catboost) (3.8.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.10/dist-packages (from catboost) (1.26.4)
# Requirement already satisfied: pandas>=0.24 in /usr/local/lib/python3.10/dist-packages (from catboost) (2.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.10/dist-packages (from catboost) (1.13.1)
# Requirement already satisfied: plotly in /usr/local/lib/python3.10/dist-packages (from catboost) (5.24.1)
# Requirement already satisfied: six in /usr/local/lib/python3.10/dist-packages (from catboost) (1.16.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.10/dist-packages (from pandas>=0.24->catboost) (2024.2)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (4.54.1)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (24.2)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.10/dist-packages (from matplotlib->catboost) (3.2.0)
# Requirement already satisfied: tenacity>=6.2.0 in /usr/local/lib/python3.10/dist-packages (from plotly->catboost) (9.0.0)
# Downloading catboost-1.2.7-cp310-cp310-manylinux2014_x86_64.whl (98.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.7/98.7 MB 6.8 MB/s eta 0:00:00
# Installing collected packages: catboost
# Successfully installed catboost-1.2.7

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import StratifiedKFold, cross_validate



# Define the kNN model with default parameters
knn = KNeighborsClassifier()
# Fit the model on the entire dataset
knn.fit(X, y)
# Get predictions on the entire dataset
y_pred = knn.predict(X)

# Create a DataFrame with actual and predicted values
output_df = pd.DataFrame({
    'Actual': y,
    'Predicted': y_pred
})
# Save the DataFrame to an Excel file
output_df.to_excel('predictions_output.xlsx', index=False)
# Inform the user the file has been saved
print("The actual and predicted values have been saved to 'predictions_output.xlsx'.")
# Out:
# The actual and predicted values have been saved to 'predictions_output.xlsx'.

# %%
from sklearn.svm import SVC


# Define the SVC model with default parameters
svc = SVC(random_state=42)

# Fit the model on the entire dataset
svc.fit(X, y)



# Get predictions on the entire dataset
y_pred = svc.predict(X)

# Create a DataFrame with actual and predicted values
output_df = pd.DataFrame({
    'Actual': y,
    'Predicted': y_pred
})

# Save the DataFrame to an Excel file
output_df.to_excel('predictions_output.xlsx', index=False)

# Inform the user the file has been saved
print("The actual and predicted values have been saved to 'predictions_output.xlsx'.")
# Out:
# The actual and predicted values have been saved to 'predictions_output.xlsx'.

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import RandomizedSearchCV, StratifiedKFold, cross_validate
from sklearn.preprocessing import StandardScaler
# Define the Decision Tree model
dtc = DecisionTreeClassifier(random_state=42)

# Fit the model on the entire dataset
dtc.fit(X, y)



# Get predictions on the entire dataset
y_pred = dtc.predict(X)

# Create a DataFrame with actual and predicted values
output_df = pd.DataFrame({
    'Actual': y,
    'Predicted': y_pred
})

# Save the DataFrame to an Excel file
output_df.to_excel('predictions_output.xlsx', index=False)

# Inform the user the file has been saved
print("The actual and predicted values have been saved to 'predictions_output.xlsx'.")
# Out:
# The actual and predicted values have been saved to 'predictions_output.xlsx'.

# %%
from sklearn.naive_bayes import GaussianNB

# Define the Gaussian Naive Bayes model
gnb = GaussianNB()

# Fit the model on the entire dataset
gnb.fit(X, y)



# Get predictions on the entire dataset
y_pred = gnb.predict(X)

# Create a DataFrame with actual and predicted values
output_df = pd.DataFrame({
    'Actual': y,
    'Predicted': y_pred
})

# Save the DataFrame to an Excel file
output_df.to_excel('predictions_output.xlsx', index=False)

# Inform the user the file has been saved
print("The actual and predicted values have been saved to 'predictions_output.xlsx'.")
# Out:
# The actual and predicted values have been saved to 'predictions_output.xlsx'.

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import StratifiedKFold

# Define the Random Forest model
rf = RandomForestClassifier(random_state=42)

# Fit the model on the entire dataset
rf.fit(X, y)


# Get predictions on the entire dataset
y_pred = rf.predict(X)

# Create a DataFrame with actual and predicted values
output_df = pd.DataFrame({
    'Actual': y,
    'Predicted': y_pred
})

# Save the DataFrame to an Excel file
output_df.to_excel('predictions_output.xlsx', index=False)

# Inform the user the file has been saved
print("The actual and predicted values have been saved to 'predictions_output.xlsx'.")
# Out:
# The actual and predicted values have been saved to 'predictions_output.xlsx'.

# %%
from sklearn.linear_model import LogisticRegression

lr = LogisticRegression(random_state=42, max_iter=1000)

# Fit the model on the entire dataset
lr.fit(X, y)

# Get predictions on the entire dataset
y_pred = lr.predict(X)

# Create a DataFrame with actual and predicted values
output_df = pd.DataFrame({
    'Actual': y,
    'Predicted': y_pred
})

# Save the DataFrame to an Excel file
output_df.to_excel('predictions_output.xlsx', index=False)

# Inform the user the file has been saved
print("The actual and predicted values have been saved to 'predictions_output.xlsx'.")
# Out:
# The actual and predicted values have been saved to 'predictions_output.xlsx'.

# %%
from sklearn.neural_network import MLPClassifier

# Define the MLP Classifier model
mlp = MLPClassifier(random_state=42, max_iter=1000)

# Fit the model on the entire dataset
mlp.fit(X, y)

# Get predictions on the entire dataset
y_pred = mlp.predict(X)

# Create a DataFrame with actual and predicted values
output_df = pd.DataFrame({
    'Actual': y,
    'Predicted': y_pred
})

# Save the DataFrame to an Excel file
output_df.to_excel('predictions_output.xlsx', index=False)

# Inform the user the file has been saved
print("The actual and predicted values have been saved to 'predictions_output.xlsx'.")
# Out:
# The actual and predicted values have been saved to 'predictions_output.xlsx'.

# %%
from xgboost import XGBClassifier
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import StratifiedKFold

xgb = XGBClassifier(random_state=42)

# Fit the model on the entire dataset
xgb.fit(X, y)


# Get predictions on the entire dataset
y_pred = xgb.predict(X)

# Create a DataFrame with actual and predicted values
output_df = pd.DataFrame({
    'Actual': y,
    'Predicted': y_pred
})

# Save the DataFrame to an Excel file
output_df.to_excel('predictions_output.xlsx', index=False)

# Inform the user the file has been saved
print("The actual and predicted values have been saved to 'predictions_output.xlsx'.")
# Out:
# The actual and predicted values have been saved to 'predictions_output.xlsx'.

# %%
from catboost import CatBoostClassifier

# Define the CatBoostClassifier model
catboost_model = CatBoostClassifier(
    random_seed=42,

)

# Fit the model on the entire dataset
catboost_model.fit(X, y)
# Out:
# Learning rate set to 0.066692
# 0:	learn: 1.0734161	total: 195ms	remaining: 3m 14s
# 1:	learn: 1.0503334	total: 275ms	remaining: 2m 17s
# 2:	learn: 1.0244935	total: 346ms	remaining: 1m 55s
# 3:	learn: 1.0106278	total: 418ms	remaining: 1m 44s
# 4:	learn: 0.9842963	total: 488ms	remaining: 1m 37s
# 5:	learn: 0.9738874	total: 561ms	remaining: 1m 32s
# 6:	learn: 0.9496809	total: 629ms	remaining: 1m 29s
# 7:	learn: 0.9308447	total: 667ms	remaining: 1m 22s
# 8:	learn: 0.9063583	total: 755ms	remaining: 1m 23s
# 9:	learn: 0.8919575	total: 824ms	remaining: 1m 21s
# 10:	learn: 0.8743282	total: 892ms	remaining: 1m 20s
# 11:	learn: 0.8569635	total: 962ms	remaining: 1m 19s
# 12:	learn: 0.8367121	total: 1.03s	remaining: 1m 18s
# 13:	learn: 0.8190417	total: 1.09s	remaining: 1m 17s
# 14:	learn: 0.8048682	total: 1.17s	remaining: 1m 16s
# 15:	learn: 0.7935306	total: 1.24s	remaining: 1m 16s
# 431:	learn: 0.0280754	total: 32.7s	remaining: 43s
# 432:	learn: 0.0279730	total: 32.7s	remaining: 42.9s
# 433:	learn: 0.0278792	total: 32.8s	remaining: 42.8s
# 434:	learn: 0.0277612	total: 32.9s	remaining: 42.7s
# 435:	learn: 0.0276840	total: 33s	remaining: 42.6s
# 436:	learn: 0.0276006	total: 33s	remaining: 42.6s
# 437:	learn: 0.0275179	total: 33.1s	remaining: 42.5s
# 438:	learn: 0.0274566	total: 33.2s	remaining: 42.4s
# 439:	learn: 0.0274037	total: 33.2s	remaining: 42.3s
# 440:	learn: 0.0273290	total: 33.3s	remaining: 42.2s
# 441:	learn: 0.0272535	total: 33.4s	remaining: 42.1s
# 442:	learn: 0.0271672	total: 33.4s	remaining: 42s
# 443:	learn: 0.0271175	total: 33.5s	remaining: 41.9s
# 444:	learn: 0.0270327	total: 33.5s	remaining: 41.8s

# %%
y_pred = catboost_model.predict(X)
y_pred = y_pred.flatten()
output_df = pd.DataFrame({
    'Actual': y,
    'Predicted': y_pred
})
output_df.to_excel('predictions_output.xlsx', index=False)
print("The actual and predicted values have been saved to 'predictions_output.xlsx'.")
# Out:
# The actual and predicted values have been saved to 'predictions_output.xlsx'.

# %%
from sklearn.ensemble import AdaBoostClassifier
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import RandomizedSearchCV, StratifiedKFold, cross_validate
from sklearn.preprocessing import StandardScaler
from imblearn.over_sampling import SMOTE


# Define the base estimator (Decision Tree) for AdaBoost
base_estimator = DecisionTreeClassifier(max_depth=1)  # You can adjust the depth

# Define the AdaBoost model
ada_model = AdaBoostClassifier(

    random_state=42
)

# Fit the model on the entire dataset
ada_model.fit(X, y)

# Get predictions on the entire dataset
y_pred = ada_model.predict(X)

# Create a DataFrame with actual and predicted values
output_df = pd.DataFrame({
    'Actual': y,
    'Predicted': y_pred
})

# Save the DataFrame to an Excel file
output_df.to_excel('predictions_output.xlsx', index=False)

# Inform the user the file has been saved
print("The actual and predicted values have been saved to 'predictions_output.xlsx'.")
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py:776: UserWarning: The least populated class in y has only 7 members, which is less than n_splits=10.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/ensemble/_weight_boosting.py:527: FutureWarning: The SAMME.R algorithm (the default) is deprecated and will be removed in 1.6. Use the SAMME algorithm to circumvent this warning.
#   warnings.warn(
# Evaluation Metrics: {'Accuracy Mean': 0.6833, 'Accuracy STD': 0.2494, 'Precision Mean': 0.5778, 'Precision STD': 0.3004, 'Recall Mean': 0.6667, 'Recall STD': 0.2687, 'F1 Mean': 0.5989, 'F1 STD': 0.2948}
# The actual and predicted values have been saved to 'predictions_output.xlsx'.
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.model_selection import RandomizedSearchCV, StratifiedKFold, cross_validate

# Define the ExtraTreesClassifier model
et_model = ExtraTreesClassifier(
    random_state=42,

)

# Fit the model on the entire dataset
et_model.fit(X, y)


# Get predictions on the entire dataset
y_pred = et_model.predict(X)

# Create a DataFrame with actual and predicted values
output_df = pd.DataFrame({
    'Actual': y,
    'Predicted': y_pred
})

# Save the DataFrame to an Excel file
output_df.to_excel('predictions_output.xlsx', index=False)

# Inform the user the file has been saved
print("The actual and predicted values have been saved to 'predictions_output.xlsx'.")
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py:776: UserWarning: The least populated class in y has only 7 members, which is less than n_splits=10.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Evaluation Metrics: {'Accuracy Mean': 0.6333, 'Accuracy STD': 0.2363, 'Precision Mean': 0.5472, 'Precision STD': 0.2739, 'Recall Mean': 0.625, 'Recall STD': 0.272, 'F1 Mean': 0.5578, 'F1 STD': 0.2697}
# The actual and predicted values have been saved to 'predictions_output.xlsx'.
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.model_selection import RandomizedSearchCV, StratifiedKFold, cross_validate

gb_model = GradientBoostingClassifier(
    random_state=42,

)

# Fit the model on the entire dataset
gb_model.fit(X, y)


# Get predictions on the entire dataset
y_pred = gb_model.predict(X)

# Create a DataFrame with actual and predicted values
output_df = pd.DataFrame({
    'Actual': y,
    'Predicted': y_pred
})

# Save the DataFrame to an Excel file
output_df.to_excel('predictions_output.xlsx', index=False)

# Inform the user the file has been saved
print("The actual and predicted values have been saved to 'predictions_output.xlsx'.")#29
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/model_selection/_split.py:776: UserWarning: The least populated class in y has only 7 members, which is less than n_splits=10.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Evaluation Metrics: {'Accuracy Mean': 0.7833, 'Accuracy STD': 0.1944, 'Precision Mean': 0.6944, 'Precision STD': 0.2814, 'Recall Mean': 0.7667, 'Recall STD': 0.2261, 'F1 Mean': 0.7111, 'F1 STD': 0.2603}
# The actual and predicted values have been saved to 'predictions_output.xlsx'.
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1531: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in labels with no true samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
